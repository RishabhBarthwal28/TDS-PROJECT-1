# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/users.csv')
df.head()
# Out:
#              login            name           company  \
# 0          IDouble        Alp ₿📈🚀🌕  IDEX/USD @IDEXIO
# 1  TheOfficialFloW     Andy Nguyen               NaN
# 2          Seldaek  Jordi Boggiano         PACKAGIST
# 3            riscv          RISC-V               NaN
# 4      JonnyBurger    Jonny Burger      REMOTION-DEV
#
#                       location                          email  hireable  \
# 0          Zurich, Switzerland                            NaN     False
# 1                       Zurich  theofficialflow1996@gmail.com     False
# 2  Zürich, Zurich, Switzerland             j.boggiano@seld.be     False
# 3                   Zurich, CH                 info@riscv.org     False
# 4          Zurich, Switzerland                    hi@jonny.io     False
#
#                                                  bio  public_repos  followers  \
# 0  🗽 Be greedy when others are fearful and be fea...            61      32935
# ...

# %%
# Replace all True/False values in df with 'true'/'false' as strings
df = df.replace({True: 'true', False: 'false'})

# Display the updated DataFrame to confirm the changes
df.head()
# Out:
#              login            name           company  \
# 0          IDouble        Alp ₿📈🚀🌕  IDEX/USD @IDEXIO
# 1  TheOfficialFloW     Andy Nguyen               NaN
# 2          Seldaek  Jordi Boggiano         PACKAGIST
# 3            riscv          RISC-V               NaN
# 4      JonnyBurger    Jonny Burger      REMOTION-DEV
#
#                       location                          email hireable  \
# 0          Zurich, Switzerland                            NaN    false
# 1                       Zurich  theofficialflow1996@gmail.com    false
# 2  Zürich, Zurich, Switzerland             j.boggiano@seld.be    false
# 3                   Zurich, CH                 info@riscv.org    false
# 4          Zurich, Switzerland                    hi@jonny.io    false
#
#                                                  bio  public_repos  followers  \
# 0  🗽 Be greedy when others are fearful and be fea...            61      32935
# ...

# %%
# Save the DataFrame to a CSV file
df.to_csv('users.csv', index=False)

# %%
df.head()
# Out:
#              login            name           company  \
# 0          IDouble        Alp ₿📈🚀🌕  IDEX/USD @IDEXIO
# 1  TheOfficialFloW     Andy Nguyen               NaN
# 2          Seldaek  Jordi Boggiano         PACKAGIST
# 3            riscv          RISC-V               NaN
# 4      JonnyBurger    Jonny Burger      REMOTION-DEV
#
#                       location                          email hireable  \
# 0          Zurich, Switzerland                            NaN    false
# 1                       Zurich  theofficialflow1996@gmail.com    false
# 2  Zürich, Zurich, Switzerland             j.boggiano@seld.be    false
# 3                   Zurich, CH                 info@riscv.org    false
# 4          Zurich, Switzerland                    hi@jonny.io    false
#
#                                                  bio  public_repos  followers  \
# 0  🗽 Be greedy when others are fearful and be fea...            61      32935
# ...

# %%
repdf=pd.read_csv('/content/repositories.csv')

# %%
repdf.head()
# Out:
#      login                                          full_name  \
# 0  IDouble  IDouble/Market-Overview-Indexes-Forex-Metals-C...
# 1  IDouble  IDouble/Customizable-Crypto-Currency-Dashboard...
# 2  IDouble        IDouble/HTML-Crypto-Currency-Chart-Snippets
# 3  IDouble            IDouble/Forex-USD-Currency-Market-Chart
# 4  IDouble                                    IDouble/IDouble
#
#              created_at  stargazers_count  watchers_count language  \
# 0  2022-01-10T04:36:39Z               108             108     HTML
# 1  2019-06-15T09:25:48Z               210             210     HTML
# 2  2019-06-10T07:34:31Z               266             266     HTML
# 3  2022-04-26T16:10:59Z                52              52     HTML
# 4  2022-11-18T17:26:07Z                39              39      NaN
#
#    has_projects  has_wiki license_name
# 0          True      True          mit
# 1          True      True          mit
# 2          True      True          mit
# ...

# %%
# Replace all True/False values in repdf with 'true'/'false' as strings
repdf = repdf.replace({True: 'true', False: 'false'})

# %%
repdf.head()
# Out:
#      login                                          full_name  \
# 0  IDouble  IDouble/Market-Overview-Indexes-Forex-Metals-C...
# 1  IDouble  IDouble/Customizable-Crypto-Currency-Dashboard...
# 2  IDouble        IDouble/HTML-Crypto-Currency-Chart-Snippets
# 3  IDouble            IDouble/Forex-USD-Currency-Market-Chart
# 4  IDouble                                    IDouble/IDouble
#
#              created_at  stargazers_count  watchers_count language  \
# 0  2022-01-10T04:36:39Z               108             108     HTML
# 1  2019-06-15T09:25:48Z               210             210     HTML
# 2  2019-06-10T07:34:31Z               266             266     HTML
# 3  2022-04-26T16:10:59Z                52              52     HTML
# 4  2022-11-18T17:26:07Z                39              39      NaN
#
#   has_projects has_wiki license_name
# 0         true     true          mit
# 1         true     true          mit
# 2         true     true          mit
# ...

# %%
# Save the updated DataFrame to a CSV file
repdf.to_csv('repositories.csv', index=False)

# %% [markdown]
# **Q1**

# %%
# Sort users by the 'followers' column in descending order and get the top 5
top_users =df.sort_values(by='followers', ascending=False).head(5)

# Extract the 'login' column values for these top 5 users and join them into a comma-separated string
top_users_list = ', '.join(top_users['login'].tolist())
print(top_users_list)
# Out:
# IDouble, TheOfficialFloW, Seldaek, riscv, JonnyBurger

# %% [markdown]
# **Q2**

# %%
# Convert 'created_at' column to datetime if it's not already

df['created_at'] = pd.to_datetime(df['created_at'])

# Sort by 'created_at' in ascending order and get the top 5
earliest_users = df.sort_values(by='created_at', ascending=True).head(5)

# Get the login names of the earliest 5 users and join them as a comma-separated string
earliest_users_list = ', '.join(earliest_users['login'].tolist())
earliest_users_list
# Out:
# 'lejoe, uwolfer, matthiask, oscardelben, pneff'

# %% [markdown]
# **Q3 **

# %%
# Drop rows where 'license_name' is missing or empty
licenses_df = repdf[repdf['license_name'].notna() & (repdf['license_name'] != "")]

# Count the occurrences of each license and get the top 3
top_licenses = licenses_df['license_name'].value_counts().head(3)

# Get the license names and join them into a comma-separated string
top_licenses_list = ', '.join(top_licenses.index.tolist())
top_licenses_list
# Out:
# 'mit, other, apache-2.0'

# %% [markdown]
# **Q4**

# %%
df['company'].value_counts()#----#ans=GOOGLE
# Out:
# company
# GOOGLE                             53
# ETH ZURICH                         45
# MICROSOFT                          11
# NVIDIA                              5
# ESRI                                4
#                                    ..
# DFINITY                             1
# OPEN-CH                             1
# SWISSCOM (SWITZERLAND) LTD.         1
# BEIJING INSTITUTE OF TECHNOLOGY     1
# SQUIRRO                             1
# Name: count, Length: 193, dtype: int64

# %% [markdown]
# **Q5**

# %%
repdf['language'].value_counts()
#ans==python
# Out:
# language
# Python         4017
# JavaScript     3791
# C++            1588
# Java           1148
# HTML            946
#                ...
# SAS               1
# ColdFusion        1
# Eiffel            1
# Cython            1
# Vim Snippet       1
# Name: count, Length: 181, dtype: int64

# %% [markdown]
# **Q6**

# %%
 #Convert 'created_at' to datetime if not already
repdf['created_at'] = pd.to_datetime(repdf['created_at'])

# Filter for users who joined after 2020
recent_repos = repdf[repdf['created_at'].dt.year > 2020]

# Count occurrences of each language, ignoring missing values, and get the second most popular
language_counts = recent_repos['language'].value_counts()
second_most_popular_language = language_counts.index[1] if len(language_counts) > 1 else None
second_most_popular_language
# Out:
# 'TypeScript'

# %% [markdown]
# **Q7**

# %%
# Drop rows where 'language' or 'stargazers_count' is missing
language_stars_df = repdf.dropna(subset=['language', 'stargazers_count'])

# Calculate the average number of stars per language
avg_stars_per_language = language_stars_df.groupby('language')['stargazers_count'].mean()

# Get the language with the highest average stars
most_starred_language = avg_stars_per_language.idxmax()
most_starred_language
# Out:
# 'BitBake'

# %% [markdown]
# **Q8**

# %%
# Calculate 'leader_strength' as followers / (1 + following)
df['leader_strength'] = df['followers'] / (1 + df['following'])

# Sort the DataFrame by 'leader_strength' in descending order and select the top 5
top_leaders = df.sort_values(by='leader_strength', ascending=False).head(5)

# Get the login names of the top 5 users and join them as a comma-separated string
top_leaders_list = ', '.join(top_leaders['login'].tolist())
top_leaders_list
# Out:
# 'riscv, bpasero, Seldaek, egamma, ethz-asl'

# %% [markdown]
# **Q9**

# %%
# Calculate the correlation between 'followers' and 'public_repos' in df
correlation = df['followers'].corr(df['public_repos'])

# Round to 3 decimal places
correlation_rounded = round(correlation, 3)
correlation_rounded
# Out:
# 0.065

# %% [markdown]
# **Q10**

# %%
from sklearn.linear_model import LinearRegression

# Prepare the data for regression
X = df['public_repos'].values.reshape(-1, 1)  # Independent variable: public repositories
y = df['followers'].values  # Dependent variable: followers

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# The coefficient represents the estimated increase in followers per additional repository
followers_per_repo = model.coef_[0]
followers_per_repo
# Out:
# 1.4584213115032363

# %% [markdown]
# **Q11**

# %%
# Convert 'has_projects' and 'has_wiki' columns to numerical (1 for 'true', 0 for 'false')
repdf['has_projects'] = repdf['has_projects'].apply(lambda x: 1 if x == 'true' else 0)
repdf['has_wiki'] = repdf['has_wiki'].apply(lambda x: 1 if x == 'true' else 0)

# Calculate the correlation between 'has_projects' and 'has_wiki'
projects_wiki_correlation = repdf['has_projects'].corr(repdf['has_wiki'])

# Round to 3 decimal places
projects_wiki_correlation_rounded = round(projects_wiki_correlation, 3)
projects_wiki_correlation_rounded
# Out:
# 0.309

# %% [markdown]
# **Q12**

# %%
# Convert 'hireable' column to boolean if it's in string format ('true'/'false')
df['hireable'] = df['hireable'].apply(lambda x: True if x == 'true' else False)

# Calculate the average 'following' for hireable and non-hireable users
avg_following_hireable = df[df['hireable'] == True]['following'].mean()
avg_following_non_hireable = df[df['hireable'] == False]['following'].mean()

# Calculate the difference between the two averages, rounded to 3 decimal places
following_difference = round(avg_following_hireable - avg_following_non_hireable, 3)
following_difference
# Out:
# -824.371

# %% [markdown]
# **Q13**

# %%
from sklearn.linear_model import LinearRegression

# Filter out users without bios and calculate the word count of each bio
df_with_bio = df[df['bio'].notna() & (df['bio'] != "")].copy()
df_with_bio['bio_word_count'] = df_with_bio['bio'].apply(lambda x: len(x.split()))

# Prepare data for regression
X_bio_words = df_with_bio['bio_word_count'].values.reshape(-1, 1)  # Independent variable: bio word count
y_followers = df_with_bio['followers'].values  # Dependent variable: followers

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X_bio_words, y_followers)

# Get the slope (impact) of bio word count on followers
bio_word_slope = round(model.coef_[0], 3)
bio_word_slope
# Out:
# 40.199

# %% [markdown]
# **Q14**

# %%
import pandas as pd

# Convert 'created_at' to datetime
repdf['created_at'] = pd.to_datetime(repdf['created_at'])

# Filter for weekend days (Saturday: 5, Sunday: 6)
weekend_repos = repdf[repdf['created_at'].dt.dayofweek >= 5]

# Count repositories per user
top_users_weekend = weekend_repos['login'].value_counts().head(5)

# Get the logins of the top 5 users in order
top_users_logins = top_users_weekend.index.tolist()

# Print the logins as a comma-separated string
print(", ".join(top_users_logins))
# Out:
# JonnyBurger, syzer, kynan, nicnocquee, zouzias

# %% [markdown]
# **Q15**

# %%
import pandas as pd

# Load the users dataset
df = pd.read_csv('users.csv')

# Calculate the fraction of users with email when hireable is True
hireable_with_email = df[df['hireable'] == True]['email'].notna().mean()

# Calculate the fraction of users with email when hireable is False
not_hireable_with_email = df[df['hireable'] != True]['email'].notna().mean()

# Calculate the difference
difference = hireable_with_email - not_hireable_with_email

# Print the difference rounded to 3 decimal places
print(round(difference, 3))
# Out:
# 0.062

# %% [markdown]
# **Q16**

# %%
# Filter out users without a name and trim whitespace
df_with_names = df[df['name'].notna() & (df['name'] != "")].copy()
df_with_names['surname'] = df_with_names['name'].apply(lambda x: x.strip().split()[-1])

# Count occurrences of each surname and find the most common one(s)
surname_counts = df_with_names['surname'].value_counts()
max_count = surname_counts.max()
most_common_surnames = surname_counts[surname_counts == max_count].index.tolist()

# Sort the surnames alphabetically and join them as a comma-separated string
most_common_surnames_sorted = ', '.join(sorted(most_common_surnames))
most_common_surnames_sorted
# Out:
# 'Li, Wang'
